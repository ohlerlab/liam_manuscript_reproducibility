# %%
# lpr_scregseg environment

# %% [markdown]
# # Combine data for extended treatment-control use case as part of revisions r1
# We created an identical feature set for the ATAC data as we previously used for the additional data.
#
# Here, we combine all preprocessed data sets into a single anndata object.

# %%
import os
import pandas as pd
from anndata import read_h5ad
import scanpy as sc
import scregseg
import matplotlib.pyplot as plt
import numpy as np

# %%
adata_dict = {}

# %%
adata_dict['treatment_control_use_case'] = read_h5ad("liam_manuscript_reproducibility/data/derived/Mimitou2021/DOGMA_seq/preprocessed_DOGMA.h5ad")

# %%
adata_dict['perm_cells'] = read_h5ad("liam_manuscript_reproducibility/data/derived/Swanson2021/perm_cells/preprocessed_perm_cells.h5ad")
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata_dict['10k_sorted_nuclei'] = read_h5ad("liam_manuscript_reproducibility/data/derived/10x/10k_sorted/preprocessed_10k_sorted_nuclei.h5ad")
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata_dict['perm_cells'].var_names_make_unique()

# %%
adata_dict['10k_sorted_nuclei'].var_names_make_unique()

# %%
adata_dict.keys()
# Out:
# dict_keys(['treatment_control_use_case', 'perm_cells', '10k_sorted_nuclei'])

# %%
# Combine datasets
adata_concat =  sc.AnnData.concatenate(*[adata_dict[key] for key in adata_dict.keys()],
                                           join='inner', batch_key='data_set',
                                           batch_categories=adata_dict.keys(),
                                           uns_merge=None, index_unique='_', fill_value=None)

# %%
adata_concat.obs.columns
# Out:
# Index(['batch', 'counts', 'original_barcodes', 'n_fragments', 'n_duplicate',
#        'n_mito', 'n_unique', 'altius_count', 'altius_frac',
#        'gene_bodies_count', 'gene_bodies_frac', 'peaks_count', 'peaks_frac',
#        'tss_count', 'tss_frac', 'cell_name', 'well_id', 'chip_id', 'batch_id',
#        'pbmc_sample_id', 'DoubletScore', 'DoubletEnrichment', 'TSSEnrichment',
#        'celltype', 'broad_celltype', 'pass_rnaQC', 'pass_accQC', 'data_set'],
#       dtype='object')

# %%
adata_concat
# Out:
# AnnData object with n_obs × n_vars = 44580 × 36588
#     obs: 'batch', 'counts', 'original_barcodes', 'n_fragments', 'n_duplicate', 'n_mito', 'n_unique', 'altius_count', 'altius_frac', 'gene_bodies_count', 'gene_bodies_frac', 'peaks_count', 'peaks_frac', 'tss_count', 'tss_frac', 'cell_name', 'well_id', 'chip_id', 'batch_id', 'pbmc_sample_id', 'DoubletScore', 'DoubletEnrichment', 'TSSEnrichment', 'celltype', 'broad_celltype', 'pass_rnaQC', 'pass_accQC', 'data_set'
#     var: 'gene_ids', 'feature_types', 'genome-10k_sorted_nuclei', 'genome-perm_cells'
#     obsm: 'ATAC'

# %%
adata_concat.obs
# Out:
#                                                                 batch  counts  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...     DOGMA_DIG_CTRL   942.0
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...     DOGMA_DIG_CTRL  3439.0
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...     DOGMA_DIG_CTRL  1773.0
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...     DOGMA_DIG_CTRL  3826.0
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...     DOGMA_DIG_CTRL  1979.0
# ...                                                               ...     ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                10k_sorted_nuclei     NaN
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                10k_sorted_nuclei     NaN
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                10k_sorted_nuclei     NaN
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                10k_sorted_nuclei     NaN
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                10k_sorted_nuclei     NaN
#
#                                                    original_barcodes  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...               NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...               NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...               NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...               NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...               NaN
# ...                                                              ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                             NaN
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                             NaN
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                             NaN
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                             NaN
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                             NaN
#
#                                                     n_fragments  n_duplicate  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...          NaN          NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...          NaN          NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...          NaN          NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...          NaN          NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...          NaN          NaN
# ...                                                         ...          ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                        NaN          NaN
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                        NaN          NaN
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                        NaN          NaN
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                        NaN          NaN
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                        NaN          NaN
#
#                                                     n_mito  n_unique  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...     NaN       NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...     NaN       NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...     NaN       NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...     NaN       NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...     NaN       NaN
# ...                                                    ...       ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                   NaN       NaN
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                   NaN       NaN
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                   NaN       NaN
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                   NaN       NaN
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                   NaN       NaN
#
#                                                     altius_count  altius_frac  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...           NaN          NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...           NaN          NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...           NaN          NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...           NaN          NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...           NaN          NaN
# ...                                                          ...          ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                         NaN          NaN
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                         NaN          NaN
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                         NaN          NaN
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                         NaN          NaN
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                         NaN          NaN
#
#                                                     gene_bodies_count  ...  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...                NaN  ...
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...                NaN  ...
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...                NaN  ...
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...                NaN  ...
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...                NaN  ...
# ...                                                               ...  ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                              NaN  ...
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                              NaN  ...
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                              NaN  ...
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                              NaN  ...
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                              NaN  ...
#
#                                                     batch_id  pbmc_sample_id  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...       NaN             NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...       NaN             NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...       NaN             NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...       NaN             NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...       NaN             NaN
# ...                                                      ...             ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                     NaN             NaN
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                     NaN             NaN
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                     NaN             NaN
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                     NaN             NaN
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                     NaN             NaN
#
#                                                     DoubletScore  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...           NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...           NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...           NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...           NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...           NaN
# ...                                                          ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                         NaN
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                         NaN
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                         NaN
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                         NaN
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                         NaN
#
#                                                     DoubletEnrichment  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...                NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...                NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...                NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...                NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...                NaN
# ...                                                               ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                              NaN
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                              NaN
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                              NaN
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                              NaN
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                              NaN
#
#                                                     TSSEnrichment  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...            NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...            NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...            NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...            NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...            NaN
# ...                                                           ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                          NaN
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                          NaN
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                          NaN
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                          NaN
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                          NaN
#
#                                                                   celltype  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...                     NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...                     NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...                     NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...                     NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...                     NaN
# ...                                                                    ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                     naive CD8 T cells
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                     naive CD8 T cells
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                CD56 (bright) NK cells
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                    memory CD4 T cells
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                  effector CD8 T cells
#
#                                                    broad_celltype pass_rnaQC  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...            NaN        NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...            NaN        NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...            NaN        NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...            NaN        NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...            NaN        NaN
# ...                                                           ...        ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                     Lymphoid       True
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                     Lymphoid       True
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                     Lymphoid       True
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                     Lymphoid       True
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                     Lymphoid       True
#
#                                                    pass_accQC  \
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...        NaN
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...        NaN
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...        NaN
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...        NaN
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...        NaN
# ...                                                       ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                     True
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                     True
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                     True
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                     True
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                     True
#
#                                                                       data_set
# AAACAGCCATAGCGAG-1_DOGMA_DIG_CTRL_treatment_con...  treatment_control_use_case
# AAACAGCCATCCATCT-1_DOGMA_DIG_CTRL_treatment_con...  treatment_control_use_case
# AAACAGCCATTGACAT-1_DOGMA_DIG_CTRL_treatment_con...  treatment_control_use_case
# AAACATGCAAAGCGCA-1_DOGMA_DIG_CTRL_treatment_con...  treatment_control_use_case
# AAACATGCACCTAATG-1_DOGMA_DIG_CTRL_treatment_con...  treatment_control_use_case
# ...                                                                        ...
# TTTGTTGGTGACATGC-1_10k_sorted_nuclei                         10k_sorted_nuclei
# TTTGTTGGTGTTAAAC-1_10k_sorted_nuclei                         10k_sorted_nuclei
# TTTGTTGGTTAGGATT-1_10k_sorted_nuclei                         10k_sorted_nuclei
# TTTGTTGGTTGGTTAG-1_10k_sorted_nuclei                         10k_sorted_nuclei
# TTTGTTGGTTTGCAGA-1_10k_sorted_nuclei                         10k_sorted_nuclei
#
# [44580 rows x 28 columns]

# %%
adata_concat.write("liam_manuscript_reproducibility/data/derived/Mimitou2021/DOGMA_seq/extended_treatment_control_use_case_revisions_r1.h5ad")
# Out:
# ... storing 'batch' as categorical
# ... storing 'original_barcodes' as categorical
# ... storing 'cell_name' as categorical

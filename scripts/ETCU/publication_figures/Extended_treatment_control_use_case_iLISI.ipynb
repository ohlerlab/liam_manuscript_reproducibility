# %%
# Compute iLISI for all extended use case models
# run on max254 (leg)
# run on max042
# January 15th, 2024

# Anaconda environment: scib_v1.0.1_min

# %%
import anndata as ad
import numpy as np
import pandas as pd
import scib
import matplotlib.pyplot as plt
from pandas.api.types import CategoricalDtype
# Out:
# During startup - Warning messages:
# 1: Setting LC_CTYPE failed, using "C"
# 2: Setting LC_COLLATE failed, using "C"
# 3: Setting LC_TIME failed, using "C"
# 4: Setting LC_MESSAGES failed, using "C"
# 5: Setting LC_MONETARY failed, using "C"
# 6: Setting LC_PAPER failed, using "C"
# 7: Setting LC_MEASUREMENT failed, using "C"

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
models = []

# %%
for factor in ['_x1', '_x5', '_x10', '_x25', '_x50', '_x100']:
    if factor == '_x1':
        models += ['BAVAE_sample_100_extended_use_case',
                   'VAE_100_extended_use_case']
    else:
        models += ['BAVAE_sample_100_extended_use_case{}'.format(factor)]

# %%
# 2023-12-12
# Manual fix to line 594 of scib/metrics/lisi.py
# changed: print(i[1] + " has not enough neighbors.")
# to: print(str(i[1]) + " has not enough neighbors.")

# %%
score_dict = {}
for model in models:
    score_dict[model] = {}
    adata = ad.read_h5ad('./../../../models/ETCU/{}/adata.h5ad'.format(model))
    embedding = ad.AnnData(adata.obsm['embedding'], obs=adata.obs, obsm=adata.obsm, uns=adata.uns, obsp=adata.obsp)
    score_dict[model]['iLISI_sample'] = scib.me.lisi.ilisi_graph(embedding, batch_key='sample', multiprocessing=True)
    
    # DOGMA-seq-specific metrics
    embedding_DOGMA = embedding[embedding.obs['sample'].apply(lambda x: 'DOGMA' in x).values.tolist()].copy()
    embedding_DOGMA.obs['DOGMA_rep'] = embedding_DOGMA.obs['sample'].apply(lambda x: 'Rep1' if 'DIG' in x else 'Rep2').astype('category')
    embedding_DOGMA.obs['DOGMA_cond'] = embedding_DOGMA.obs['sample'].apply(lambda x: 'Ctrl' if 'CTRL' in x else 'Stim').astype('category')
    
    score_dict[model]['iLISI_DOGMA_replicate'] = scib.me.lisi.ilisi_graph(embedding_DOGMA, batch_key='DOGMA_rep', multiprocessing=True)
    score_dict[model]['iLISI_DOGMA_condition'] = scib.me.lisi.ilisi_graph(embedding_DOGMA, batch_key='DOGMA_cond', multiprocessing=True)
      
    # 10x annotated data specific metrics
    ### asw_label
    embedding_10x = embedding[embedding.obs['sample']== '10k_sorted_nuclei'].copy()
    score = scib.me.silhouette(
        embedding_10x,
        group_key='celltype',
        embed='embedding')
    score_dict[model]['asw_label_10k_sorted_nuclei'] = score
    
    ### nmi
    scib.cl.opt_louvain(
        embedding_10x,
        label_key='celltype',
        cluster_key='cluster',
        plot=False,
        inplace=True,
        force=True
    )

    score = scib.me.nmi(
        embedding_10x,
        group1='cluster',
        group2='celltype'
    )
    
    score_dict[model]['nmi_10k_sorted_nuclei'] = score
# Out:
# /tmp/6661713.1.all.q/lisi_clo5fdvj/input.mtx /tmp/6661713.1.all.q/lisi_clo5fdvj/
# /tmp/6661713.1.all.q/lisi_4xj862du/input.mtx /tmp/6661713.1.all.q/lisi_4xj862du/
# File has no entries. Doing nothing.
# 7290 has not enough neighbors.
# 5550 has not enough neighbors.
# 6792 has not enough neighbors.
# 7709 has not enough neighbors.
# /tmp/6661713.1.all.q/lisi_vwvndw94/input.mtx /tmp/6661713.1.all.q/lisi_vwvndw94/
# File has no entries. Doing nothing.
# 7290 has not enough neighbors.
# 5550 has not enough neighbors.
# 6792 has not enough neighbors.
# 7709 has not enough neighbors.
# Clustering...
# resolution: 0.1, nmi: 0.7482322334025422
# resolution: 0.2, nmi: 0.8126506752755652
# resolution: 0.3, nmi: 0.7905772548251082
# resolution: 0.4, nmi: 0.7894024625745543
# resolution: 0.5, nmi: 0.7877649747371462
# resolution: 0.6, nmi: 0.7772751762063956
# resolution: 0.7, nmi: 0.7758296982227743
# resolution: 0.8, nmi: 0.7618093068583202
# resolution: 0.9, nmi: 0.7622435290540109
# resolution: 1.0, nmi: 0.7532487887906111
# resolution: 1.1, nmi: 0.7439774354317982
# resolution: 1.2, nmi: 0.7542626286799125
# resolution: 1.3, nmi: 0.7362169134198391
# resolution: 1.4, nmi: 0.7257281233328197
# resolution: 1.5, nmi: 0.7262011502545966
# resolution: 1.6, nmi: 0.7170201503336544
# resolution: 1.7, nmi: 0.7233079719746588
# resolution: 1.8, nmi: 0.7090732797399579
# resolution: 1.9, nmi: 0.7170863533993959
# resolution: 2.0, nmi: 0.7053467941894307
# optimised clustering against celltype
# optimal cluster resolution: 0.2
# optimal score: 0.8126506752755652
# /tmp/6661713.1.all.q/lisi_xlzc6c14/input.mtx /tmp/6661713.1.all.q/lisi_xlzc6c14/
# /tmp/6661713.1.all.q/lisi_d762vwwi/input.mtx /tmp/6661713.1.all.q/lisi_d762vwwi/
# File has no entries. Doing nothing.
# /tmp/6661713.1.all.q/lisi_ge14oaus/input.mtx /tmp/6661713.1.all.q/lisi_ge14oaus/
# File has no entries. Doing nothing.
# Clustering...
# resolution: 0.1, nmi: 0.7671153714102054
# resolution: 0.2, nmi: 0.8359133528472829
# resolution: 0.3, nmi: 0.8404117022586528
# resolution: 0.4, nmi: 0.8170741522260563
# resolution: 0.5, nmi: 0.8028366881795002
# resolution: 0.6, nmi: 0.8007932625010938
# resolution: 0.7, nmi: 0.7858907336157325
# resolution: 0.8, nmi: 0.7847502914322408
# resolution: 0.9, nmi: 0.7831301241605886
# resolution: 1.0, nmi: 0.7754580209616186
# resolution: 1.1, nmi: 0.7550276293737661
# resolution: 1.2, nmi: 0.7585601086322532
# resolution: 1.3, nmi: 0.755805017212769
# resolution: 1.4, nmi: 0.7493639122522856
# resolution: 1.5, nmi: 0.7429899646370914
# resolution: 1.6, nmi: 0.7474274584539545
# resolution: 1.7, nmi: 0.7434913826391014
# resolution: 1.8, nmi: 0.747294559622638
# resolution: 1.9, nmi: 0.7364598026432397
# resolution: 2.0, nmi: 0.7337103525829876
# optimised clustering against celltype
# optimal cluster resolution: 0.3
# optimal score: 0.8404117022586528
# /tmp/6661713.1.all.q/lisi_x1zj1ab9/input.mtx /tmp/6661713.1.all.q/lisi_x1zj1ab9/
# /tmp/6661713.1.all.q/lisi_y455n99s/input.mtx /tmp/6661713.1.all.q/lisi_y455n99s/
# File has no entries. Doing nothing.
# /tmp/6661713.1.all.q/lisi_qc3otnpc/input.mtx /tmp/6661713.1.all.q/lisi_qc3otnpc/
# File has no entries. Doing nothing.
# Clustering...
# resolution: 0.1, nmi: 0.7747950641948312
# resolution: 0.2, nmi: 0.7750283479920625
# resolution: 0.3, nmi: 0.7708335719132866
# resolution: 0.4, nmi: 0.7668438385657993
# resolution: 0.5, nmi: 0.7453509434544549
# resolution: 0.6, nmi: 0.7467338475668508
# resolution: 0.7, nmi: 0.7476709278201532
# resolution: 0.8, nmi: 0.7444833362277654
# resolution: 0.9, nmi: 0.7458525067958154
# resolution: 1.0, nmi: 0.7385066673556339
# resolution: 1.1, nmi: 0.7373583588164447
# resolution: 1.2, nmi: 0.7298480384692749
# resolution: 1.3, nmi: 0.7247209992328402
# resolution: 1.4, nmi: 0.7191698338003208
# resolution: 1.5, nmi: 0.722777838793234
# resolution: 1.6, nmi: 0.7157393713141086
# resolution: 1.7, nmi: 0.7160684553610974
# resolution: 1.8, nmi: 0.7052143107888135
# resolution: 1.9, nmi: 0.7000510490077934
# resolution: 2.0, nmi: 0.700800362965582
# optimised clustering against celltype
# optimal cluster resolution: 0.2
# optimal score: 0.7750283479920625
# /tmp/6661713.1.all.q/lisi_jz68bpfd/input.mtx /tmp/6661713.1.all.q/lisi_jz68bpfd/
# /tmp/6661713.1.all.q/lisi_6cgqu6ks/input.mtx /tmp/6661713.1.all.q/lisi_6cgqu6ks/
# File has no entries. Doing nothing.
# 23397 has not enough neighbors.
# 25328 has not enough neighbors.
# /tmp/6661713.1.all.q/lisi_bg21iyky/input.mtx /tmp/6661713.1.all.q/lisi_bg21iyky/
# File has no entries. Doing nothing.
# 23397 has not enough neighbors.
# 25328 has not enough neighbors.
# Clustering...
# resolution: 0.1, nmi: 0.7527587409851786
# resolution: 0.2, nmi: 0.7604875019541751
# resolution: 0.3, nmi: 0.7546758698593421
# resolution: 0.4, nmi: 0.756543478801846
# resolution: 0.5, nmi: 0.7409060511199732
# resolution: 0.6, nmi: 0.7540858495853192
# resolution: 0.7, nmi: 0.7448736459184725
# resolution: 0.8, nmi: 0.7424829768965282
# resolution: 0.9, nmi: 0.7407776195407453
# resolution: 1.0, nmi: 0.7260478957026222
# resolution: 1.1, nmi: 0.728157949485641
# resolution: 1.2, nmi: 0.7195552348005894
# resolution: 1.3, nmi: 0.7211521086598394
# resolution: 1.4, nmi: 0.7089938490825817
# resolution: 1.5, nmi: 0.7125666641125845
# resolution: 1.6, nmi: 0.7149420078393114
# resolution: 1.7, nmi: 0.7149520696857908
# resolution: 1.8, nmi: 0.709979872910761
# resolution: 1.9, nmi: 0.7066213172015926
# resolution: 2.0, nmi: 0.7078853633284187
# optimised clustering against celltype
# optimal cluster resolution: 0.2
# optimal score: 0.7604875019541751
# /tmp/6661713.1.all.q/lisi_0zu6b2kk/input.mtx /tmp/6661713.1.all.q/lisi_0zu6b2kk/
# /tmp/6661713.1.all.q/lisi_irj29bs7/input.mtx /tmp/6661713.1.all.q/lisi_irj29bs7/
# File has no entries. Doing nothing.
# 13541 has not enough neighbors.
# 14552 has not enough neighbors.
# 7482 has not enough neighbors.
# 13724 has not enough neighbors.
# 13738 has not enough neighbors.
# 3316 has not enough neighbors.
# 1589 has not enough neighbors.
# /tmp/6661713.1.all.q/lisi_9jdhojmb/input.mtx /tmp/6661713.1.all.q/lisi_9jdhojmb/
# File has no entries. Doing nothing.
# 13541 has not enough neighbors.
# 7482 has not enough neighbors.
# 14552 has not enough neighbors.
# 13724 has not enough neighbors.
# 13738 has not enough neighbors.
# 3316 has not enough neighbors.
# 1589 has not enough neighbors.
# Clustering...
# resolution: 0.1, nmi: 0.7661644728857218
# resolution: 0.2, nmi: 0.8123665705799357
# resolution: 0.3, nmi: 0.7910733182788913
# resolution: 0.4, nmi: 0.7770540475778992
# resolution: 0.5, nmi: 0.7749689077655602
# resolution: 0.6, nmi: 0.7682241933362342
# resolution: 0.7, nmi: 0.7621732906593549
# resolution: 0.8, nmi: 0.7539297503422645
# resolution: 0.9, nmi: 0.7462863219454475
# resolution: 1.0, nmi: 0.7400960874893958
# resolution: 1.1, nmi: 0.7451854745897813
# resolution: 1.2, nmi: 0.7199973212102235
# resolution: 1.3, nmi: 0.7296195456036776
# resolution: 1.4, nmi: 0.7149569876944541
# resolution: 1.5, nmi: 0.7079041571871373
# resolution: 1.6, nmi: 0.7021280347877131
# resolution: 1.7, nmi: 0.6998836590973707
# resolution: 1.8, nmi: 0.7005019020283897
# resolution: 1.9, nmi: 0.6872941099408824
# resolution: 2.0, nmi: 0.6852626438211948
# optimised clustering against celltype
# optimal cluster resolution: 0.2
# optimal score: 0.8123665705799357
# /tmp/6661713.1.all.q/lisi_ld4xyjwu/input.mtx /tmp/6661713.1.all.q/lisi_ld4xyjwu/
# /tmp/6661713.1.all.q/lisi_0xdvppk0/input.mtx /tmp/6661713.1.all.q/lisi_0xdvppk0/
# File has no entries. Doing nothing.
# 10036 has not enough neighbors.
# 20768 has not enough neighbors.
# 4825 has not enough neighbors.
# 4900 has not enough neighbors.
# 9388 has not enough neighbors.
# 23944 has not enough neighbors.
# /tmp/6661713.1.all.q/lisi_a093vwjo/input.mtx /tmp/6661713.1.all.q/lisi_a093vwjo/
# File has no entries. Doing nothing.
# 10036 has not enough neighbors.
# 20768 has not enough neighbors.
# 4825 has not enough neighbors.
# 4900 has not enough neighbors.
# 9388 has not enough neighbors.
# 23944 has not enough neighbors.
# Clustering...
# resolution: 0.1, nmi: 0.7538897534662227
# resolution: 0.2, nmi: 0.7889272663922755
# resolution: 0.3, nmi: 0.7915946455152828
# resolution: 0.4, nmi: 0.7734545044103857
# resolution: 0.5, nmi: 0.7770434813122024
# resolution: 0.6, nmi: 0.748527133810518
# resolution: 0.7, nmi: 0.7477172785509681
# resolution: 0.8, nmi: 0.7396527271383466
# resolution: 0.9, nmi: 0.7428353586584083
# resolution: 1.0, nmi: 0.7384454343159705
# resolution: 1.1, nmi: 0.7253615427198111
# resolution: 1.2, nmi: 0.7174366646605692
# resolution: 1.3, nmi: 0.7202618210040869
# resolution: 1.4, nmi: 0.7137346914961155
# resolution: 1.5, nmi: 0.7160077445737598
# resolution: 1.6, nmi: 0.7130077932540212
# resolution: 1.7, nmi: 0.7159004917737976
# resolution: 1.8, nmi: 0.706304151983469
# resolution: 1.9, nmi: 0.6979674949823932
# resolution: 2.0, nmi: 0.6873139732094181
# optimised clustering against celltype
# optimal cluster resolution: 0.3
# optimal score: 0.7915946455152828
# /tmp/6661713.1.all.q/lisi_rlefd2fx/input.mtx /tmp/6661713.1.all.q/lisi_rlefd2fx/
# /tmp/6661713.1.all.q/lisi_oe7ot5cl/input.mtx /tmp/6661713.1.all.q/lisi_oe7ot5cl/
# File has no entries. Doing nothing.
# 23397 has not enough neighbors.
# 25328 has not enough neighbors.
# 11142 has not enough neighbors.
# 2418 has not enough neighbors.
# /tmp/6661713.1.all.q/lisi_5h6ll66g/input.mtx /tmp/6661713.1.all.q/lisi_5h6ll66g/
# File has no entries. Doing nothing.
# 23397 has not enough neighbors.
# 25328 has not enough neighbors.
# 11142 has not enough neighbors.
# 2418 has not enough neighbors.
# Clustering...
# resolution: 0.1, nmi: 0.7312510517566899
# resolution: 0.2, nmi: 0.7735467194651313
# resolution: 0.3, nmi: 0.7562156755184473
# resolution: 0.4, nmi: 0.7338796993204827
# resolution: 0.5, nmi: 0.7193491932786403
# resolution: 0.6, nmi: 0.7245307637936197
# resolution: 0.7, nmi: 0.7090428174089821
# resolution: 0.8, nmi: 0.7095688555645324
# resolution: 0.9, nmi: 0.709217935678632
# resolution: 1.0, nmi: 0.7035003063741406
# resolution: 1.1, nmi: 0.7024900532077941
# resolution: 1.2, nmi: 0.6973722186188986
# resolution: 1.3, nmi: 0.6881386949322316
# resolution: 1.4, nmi: 0.6959791272848971
# resolution: 1.5, nmi: 0.6934934302121133
# resolution: 1.6, nmi: 0.687508435270345
# resolution: 1.7, nmi: 0.6834756166064052
# resolution: 1.8, nmi: 0.6897367766408504
# resolution: 1.9, nmi: 0.6854742766788731
# resolution: 2.0, nmi: 0.6905526196087691
# optimised clustering against celltype
# optimal cluster resolution: 0.2
# optimal score: 0.7735467194651313

# %%
iLISI = pd.DataFrame(score_dict).T

# %%
iLISI['Model'] = iLISI.index

# %%
iLISI['Model'].value_counts()
# Out:
# BAVAE_sample_100_extended_use_case         1
# VAE_100_extended_use_case                  1
# BAVAE_sample_100_extended_use_case_x5      1
# BAVAE_sample_100_extended_use_case_x10     1
# BAVAE_sample_100_extended_use_case_x25     1
# BAVAE_sample_100_extended_use_case_x50     1
# BAVAE_sample_100_extended_use_case_x100    1
# Name: Model, dtype: int64

# %%
iLISI
# Out:
#                                          iLISI_sample  iLISI_DOGMA_replicate  \
# BAVAE_sample_100_extended_use_case           0.378749               0.803639
# VAE_100_extended_use_case                    0.002813               0.002236
# BAVAE_sample_100_extended_use_case_x5        0.465444               0.838364
# BAVAE_sample_100_extended_use_case_x10       0.499180               0.852161
# BAVAE_sample_100_extended_use_case_x25       0.518073               0.861687
# BAVAE_sample_100_extended_use_case_x50       0.525662               0.855177
# BAVAE_sample_100_extended_use_case_x100      0.528294               0.856856
#
#                                          iLISI_DOGMA_condition  \
# BAVAE_sample_100_extended_use_case                    0.744849
# VAE_100_extended_use_case                             0.079759
# BAVAE_sample_100_extended_use_case_x5                 0.765689
# BAVAE_sample_100_extended_use_case_x10                0.777670
# BAVAE_sample_100_extended_use_case_x25                0.825707
# BAVAE_sample_100_extended_use_case_x50                0.841465
# BAVAE_sample_100_extended_use_case_x100               0.842479
#
#                                          asw_label_10k_sorted_nuclei  \
# BAVAE_sample_100_extended_use_case                          0.615471
# VAE_100_extended_use_case                                   0.622500
# BAVAE_sample_100_extended_use_case_x5                       0.614223
# BAVAE_sample_100_extended_use_case_x10                      0.605701
# BAVAE_sample_100_extended_use_case_x25                      0.608753
# BAVAE_sample_100_extended_use_case_x50                      0.606339
# BAVAE_sample_100_extended_use_case_x100                     0.595586
#
#                                          nmi_10k_sorted_nuclei  \
# BAVAE_sample_100_extended_use_case                    0.812651
# VAE_100_extended_use_case                             0.840412
# BAVAE_sample_100_extended_use_case_x5                 0.775028
# BAVAE_sample_100_extended_use_case_x10                0.760488
# BAVAE_sample_100_extended_use_case_x25                0.812367
# BAVAE_sample_100_extended_use_case_x50                0.791595
# BAVAE_sample_100_extended_use_case_x100               0.773547
#
#                                                                            Model
# BAVAE_sample_100_extended_use_case            BAVAE_sample_100_extended_use_case
# VAE_100_extended_use_case                              VAE_100_extended_use_case
# BAVAE_sample_100_extended_use_case_x5      BAVAE_sample_100_extended_use_case_x5
# BAVAE_sample_100_extended_use_case_x10    BAVAE_sample_100_extended_use_case_x10
# BAVAE_sample_100_extended_use_case_x25    BAVAE_sample_100_extended_use_case_x25
# BAVAE_sample_100_extended_use_case_x50    BAVAE_sample_100_extended_use_case_x50
# BAVAE_sample_100_extended_use_case_x100  BAVAE_sample_100_extended_use_case_x100

# %%
iLISI.to_csv("./../Evaluation/batch_removal_scores_publication_r1_20240125.csv", index=True)
